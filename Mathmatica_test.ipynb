# %%
sin(x)
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
plot[sin(x)]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Plot[Sin[x], {x, 0, 10}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Plot3D[Sin[x] Cos[y], {x, 0, 5}, {y, 1, 10}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
GraphicsGrid[{{Plot3D[Sin[x] Cos[y], {x, 0, 5}, {y, 1, 10}], 
Plot3D[Sin[x]*Cos[y], {x, 0, 5}, {y, 1, 10}, 
ColorFunction -> (Hue[#3] &), MeshFunctions -> (#3 &), 
Boxed -> False, Axes -> False]}}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Plot3D[{x^2 + y^2, -x^2 - y^2}, {x, -2, 2}, {y, -2, 2}, 
RegionFunction -> Function[{x, y, z}, x^2 + y^2 <= 4], 
BoxRatios -> Automatic]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Manipulate[Plot[Sin[x (1 + a x)], {x, 0, 6}], {a, 0, 5}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>
